built3 =  ee.Geometry.Polygon([[[17.228794,60.38884],[17.228537,60.389858],[17.228279,60.39113],[17.227592,60.391681],[17.225618,60.391512],[17.225361,60.390367],[17.223129,60.39024],[17.222271,60.389816],[17.218838,60.389816],[17.219954,60.386465],[17.221756,60.386762],[17.221842,60.387695],[17.222872,60.387313],[17.224159,60.388162],[17.224846,60.388883],[17.228794,60.38884]]])
built4 =  ee.Geometry.Polygon([[[17.243471,60.39007],[17.245445,60.392487],[17.2439,60.39342],[17.242785,60.393674],[17.241669,60.393462],[17.240982,60.391978],[17.240982,60.391257],[17.23815,60.391427],[17.236776,60.391978],[17.234888,60.389264],[17.234545,60.389816],[17.234974,60.390876],[17.232485,60.391766],[17.230339,60.391469],[17.229738,60.389264],[17.228193,60.388798],[17.227764,60.387313],[17.230768,60.38655],[17.231712,60.387398],[17.233858,60.387568],[17.233772,60.386168],[17.232914,60.385362],[17.229738,60.385362],[17.227163,60.383029],[17.22888,60.382181],[17.227163,60.381333],[17.227678,60.380696],[17.229309,60.380781],[17.230597,60.381375],[17.232571,60.381248],[17.233171,60.380654],[17.235231,60.381205],[17.234201,60.381969],[17.236519,60.382181],[17.23772,60.38252],[17.240295,60.382096],[17.242613,60.384896],[17.243128,60.386253],[17.244673,60.386889],[17.245531,60.38778],[17.244072,60.388034],[17.243471,60.39007]]])
b_union = built1.union(right=built2, maxError=1)
b2_union = b_union.union(right=built3, maxError=1)
built = b2_union.union(right=built4, maxError=1)

bare1 =  ee.Geometry.Polygon([[[17.203517,60.433446],[17.201071,60.432514],[17.200341,60.433065],[17.199955,60.433891],[17.201285,60.434208],[17.20283,60.434484],[17.203217,60.434695],[17.203989,60.434124],[17.203517,60.433446]]])
bare2 =  ee.Geometry.Polygon([[[17.235918,60.431604],[17.234974,60.429952],[17.232656,60.428427],[17.232656,60.427664],[17.234116,60.427834],[17.234459,60.426224],[17.234373,60.425546],[17.236261,60.426139],[17.235918,60.427241],[17.236261,60.429062],[17.236347,60.429952],[17.235918,60.431604]]])
bare = bare1.union(right=bare2, maxError=1)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Créez la FeatureCollection
polygons = ee.FeatureCollection([
  #ee.Feature(svämängar, {'class': 0}),
  #ee.Feature(bare, {'class': 1}),
  #ee.Feature(water, {'class': 2}),
  #ee.Feature(tree, {'class': 3}),
  ee.Feature(built, {'class': 4}),
])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
roi = ee.Geometry.Polygon([[[17.204933,60.402663],[17.204933,60.455525],[17.2645,60.455525],[17.2645,60.402663],[17.204933,60.402663]]])

img_1 = landsat_preprocessing.get_l8_cloud_free_col_dates(roi, 'NDVI', 0.6, '2013-05-01', '2013-09-30').median()
img_2 = landsat_preprocessing.get_l8_cloud_free_col_dates(roi, 'NDVI', 0.6, '2015-05-01', '2015-09-30').median()
img_3 = landsat_preprocessing.get_l8_cloud_free_col_dates(roi, 'NDVI', 0.6, '2018-05-01', '2018-09-30').median()
img_4 = landsat_preprocessing.get_l8_cloud_free_col_dates(roi, 'NDVI', 0.6, '2023-05-01', '2023-09-30').median()

def apply_scale_factors(image):
  optical_bands = image.select('SR_B.').multiply(0.0000275).add(-0.2)
  thermal_bands = image.select('ST_B.*').multiply(0.00341802).add(149.0)
  return image.addBands(optical_bands, None, True).addBands(
      thermal_bands, None, True
  )

palette = ['#d73027', '#fc8d59', '#fee08b', '#91cf60', '#1a9850']

def add_color(feature):
    class_value = feature.get('class')
    color = ee.List(palette).get(class_value)
    return feature.set({'style': {'color': color, 'width': 2}})

styled_polygons = polygons.map(add_color)

polygons_image = styled_polygons.style(**{
    'styleProperty': 'style',
    'neighborhood': 8,
})
display(img_1)
m = geemap.Map()
m.centerObject(roi, 13)
m.addLayer(apply_scale_factors(img_2).clip(roi), {'bands': ['SR_B4', 'SR_B3', 'SR_B2'], 'min': 0, 'max': 0.1}, 'Sentinel-2 Image')
#m.addLayer(polygons_image, {}, 'Polygons')
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div><style>:root {
#   --font-color-primary: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --font-color-secondary: var(--jp-content-font-color2, rgba(0, 0, 0, 0.6));
#   --font-color-accent: rgba(123, 31, 162, 1);
#   --border-color: var(--jp-border-color2, #e0e0e0);
#   --background-color: var(--jp-layout-color0, white);
#   --background-color-row-even: var(--jp-layout-color1, white);
#   --background-color-row-odd: var(--jp-layout-color2, #eeeeee);
# }
#
# html[theme="dark"],
# body[data-theme="dark"],
# body.vscode-dark {
#   --font-color-primary: rgba(255, 255, 255, 1);
#   --font-color-secondary: rgba(255, 255, 255, 0.6);
#   --font-color-accent: rgb(173, 132, 190);
#   --border-color: #2e2e2e;
#   --background-color: #111111;
#   --background-color-row-even: #111111;
#   --background-color-row-odd: #313131;
# }
#
# .ee {
#   padding: 1em;
#   line-height: 1.5em;
#   min-width: 300px;
#   max-width: 1200px;
#   overflow-y: scroll;
#   max-height: 600px;
#   border: 1px solid var(--border-color);
#   font-family: monospace;
# }
#
# .ee li {
#   list-style-type: none;
# }
#
# .ee ul {
#   padding-left: 1.5em !important;
#   margin: 0;
# }
#
# .ee > ul {
#   padding-left: 0 !important;
# }
#
# .ee-open,
# .ee-shut {
#   color: var(--font-color-secondary);
#   cursor: pointer;
#   margin: 0;
# }
#
# .ee-open:hover,
# .ee-shut:hover {
#   color: var(--font-color-primary);
# }
#
# .ee-k {
#   color: var(--font-color-accent);
#   margin-right: 6px;
# }
#
# .ee-v {
#   color: var(--font-color-primary);
# }
#
# .ee-toggle {
#   display: none;
# }
#
# .ee-shut + ul {
#   display: none;
# }
#
# .ee-open + ul {
#   display: block;
# }
#
# .ee-shut::before {
#   display: inline-block;
#   content: "▼";
#   margin-right: 6px;
#   transform: rotate(-90deg);
#   transition: transform 0.2s;
# }
#
# .ee-open::before {
#   transform: rotate(0deg);
#   display: inline-block;
#   content: "▼";
#   margin-right: 6px;
#   transition: transform 0.2s;
# }
# </style><div class='ee'><ul><li><label class='ee-shut'>Image (20 bands)<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>type:</span><span class='ee-v'>Image</span></li><li><label class='ee-shut'>bands: List (20 elements)<input type='checkbox' class='ee-toggle'></label><ul><li><label class='ee-shut'>0: "SR_B1", double, EPSG:4326<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>id:</span><span class='ee-v'>SR_B1</span></li><li><span class='ee-k'>crs:</span><span class='ee-v'>EPSG:4326</span></li><li><label class='ee-shut'>crs_transform: [1, 0, 0, 0, 1, 0]<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>0:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>2:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>3:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>4:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>5:</span><span class='ee-v'>0</span></li></ul></li><li><label class='ee-shut'>data_type: double<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>type:</span><span class='ee-v'>PixelType</span></li><li><span class='ee-k'>max:</span><span class='ee-v'>65535</span></li><li><span class='ee-k'>min:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>precision:</span><span class='ee-v'>double</span></li></ul></li></ul></li><li><label class='ee-shut'>1: "SR_B2", double, EPSG:4326<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>id:</span><span class='ee-v'>SR_B2</span></li><li><span class='ee-k'>crs:</span><span class='ee-v'>EPSG:4326</span></li><li><label class='ee-shut'>crs_transform: [1, 0, 0, 0, 1, 0]<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>0:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>2:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>3:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>4:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>5:</span><span class='ee-v'>0</span></li></ul></li><li><label class='ee-shut'>data_type: double<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>type:</span><span class='ee-v'>PixelType</span></li><li><span class='ee-k'>max:</span><span class='ee-v'>65535</span></li><li><span class='ee-k'>min:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>precision:</span><span class='ee-v'>double</span></li></ul></li></ul></li><li><label class='ee-shut'>2: "SR_B3", double, EPSG:4326<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>id:</span><span class='ee-v'>SR_B3</span></li><li><span class='ee-k'>crs:</span><span class='ee-v'>EPSG:4326</span></li><li><label class='ee-shut'>crs_transform: [1, 0, 0, 0, 1, 0]<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>0:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>2:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>3:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>4:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>5:</span><span class='ee-v'>0</span></li></ul></li><li><label class='ee-shut'>data_type: double<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>type:</span><span class='ee-v'>PixelType</span></li><li><span class='ee-k'>max:</span><span class='ee-v'>65535</span></li><li><span class='ee-k'>min:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>precision:</span><span class='ee-v'>double</span></li></ul></li></ul></li><li><label class='ee-shut'>3: "SR_B4", double, EPSG:4326<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>id:</span><span class='ee-v'>SR_B4</span></li><li><span class='ee-k'>crs:</s ...
# Map(center=[60.42909015971474, 17.23471649999347], controls=(WidgetControl(options=['position', 'transparent_b…

# %%
ee.FeatureCollection(m.draw_features).getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'type': 'FeatureCollection', 'columns': {}, 'features': []}

# %%
svamangar = ee.Geometry.MultiPolygon([
    [
        [17.220554, 60.431477],
        [17.222099, 60.429359],
        [17.223301, 60.427664],
        [17.221069, 60.427241],
        [17.220554, 60.431477]
    ],
    [
        [17.213345, 60.427664],
        [17.209568, 60.426055],
        [17.213345, 60.424614],
        [17.213345, 60.427664]
    ]
])

trees = ee.Geometry.MultiPolygon([[[17.231197, 60.415039],
      [17.238579, 60.417073],
      [17.239265, 60.415378],
      [17.238579, 60.412242],
      [17.237892, 60.410716],
      [17.229481, 60.410716],
      [17.231197, 60.415039]],
      [[17.205791, 60.413259],
      [17.215233, 60.413852],
      [17.215233, 60.410547],
      [17.208881, 60.410377],
      [17.205791, 60.413259]],
      [[17.231026, 60.434949],
      [17.222443, 60.433255],
      [17.226563, 60.429359],
      [17.231026, 60.434949]]])

water = ee.Geometry.MultiPolygon([[[17.215748, 60.428935],
      [17.219181, 60.425462],
      [17.217464, 60.421734],
      [17.215233, 60.425631],
      [17.215748, 60.428935]],[[17.25214, 60.450192],
      [17.256775, 60.447229],
      [17.24905, 60.444858],
      [17.246304, 60.446636],
      [17.25214, 60.450192]]])

built = ee.Geometry.MultiPolygon([[[17.226262, 60.449176],
      [17.226605, 60.448308],
      [17.22609, 60.447419],
      [17.227163, 60.446361],
      [17.226691, 60.44598],
      [17.225833, 60.446615],
      [17.22609, 60.447737],
      [17.225318, 60.448202],
      [17.226262, 60.449176]],[[17.228837, 60.441682],
      [17.230253, 60.441259],
      [17.23021, 60.441809],
      [17.228837, 60.441682]],[[17.22403, 60.440963],
      [17.224803, 60.440963],
      [17.224331, 60.440433],
      [17.22343, 60.44037],
      [17.22403, 60.440963]]])

crops =  ee.Geometry.Polygon([[[17.217379, 60.450962],
      [17.219696, 60.450941],
      [17.219761, 60.449629],
      [17.217444, 60.449661],
      [17.217379, 60.450962]]])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Function to apply scale factors to Sentinel-2 images
def apply_scale_factors_s2(image):
    optical_bands = image.select('B.*').multiply(0.0001)
    return image.addBands(optical_bands, None, True)

# Define Sentinel-2 image collections
img_1_s2 = ee.ImageCollection('COPERNICUS/S2_HARMONIZED')\
        .filterBounds(roi)\
        .filterDate('2023-05-01', '2023-06-01')\
        .filter(ee.Filter.lte('CLOUDY_PIXEL_PERCENTAGE', 20)).median()

img_2_s2 = ee.ImageCollection('COPERNICUS/S2_HARMONIZED')\
        .filterBounds(roi)\
        .filterDate('2017-05-01', '2017-09-30')\
        .filter(ee.Filter.lte('CLOUDY_PIXEL_PERCENTAGE', 20)).median()

# Apply scale factors
img_1_s2 = apply_scale_factors_s2(img_1_s2)
img_2_s2 = apply_scale_factors_s2(img_2_s2)

palette = ['#d73027', '#fc8d59', '#fee08b', '#91cf60', '#1a9850']

def add_color(feature):
    class_value = feature.get('class')
    color = ee.List(palette).get(class_value)
    return feature.set({'style': {'color': color, 'width': 2}})

polygons = ee.FeatureCollection([
    ee.Feature(roi, {'class': 0})  # Example feature, replace with actual polygons
])

styled_polygons = polygons.map(add_color)

polygons_image = styled_polygons.style(**{
    'styleProperty': 'style',
    'neighborhood': 8,
})

# Display the map
m = geemap.Map()
m.centerObject(roi, 13)
m.addLayer(img_1_s2.clip(roi), {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 0.2}, 'Sentinel-2 Image 2023')
#m.addLayer(img_2_s2.clip(roi), {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 0.2}, 'Sentinel-2 Image 2013')
#m.addLayer(polygons_image, {}, 'Polygons')
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[60.42909015971474, 17.23471649999347], controls=(WidgetControl(options=['position', 'transparent_b…

# %%
ee.FeatureCollection(m.draw_features).getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'type': 'FeatureCollection',
#  'columns': {'system:index': 'String'},
#  'features': [{'type': 'Feature',
#    'geometry': {'geodesic': False,
#     'type': 'Polygon',
#     'coordinates': [[[17.217379, 60.450962],
#       [17.219696, 60.450941],
#       [17.219761, 60.449629],
#       [17.217444, 60.449661],
#       [17.217379, 60.450962]]]},
#    'id': '0',
#    'properties': {}}]}

# %%
# Définir une palette de couleurs pour les classes
palette = ['#d73027', '#fc8d59', '#fee08b', '#91cf60', '#1a9850']

# Ajouter des couleurs aux polygones
def add_color(feature):
    class_value = feature.get('class')
    color = ee.List(palette).get(class_value)
    return feature.set({'style': {'color': color, 'width': 2}})

styled_polygons = polygons.map(add_color)

# Convertir les polygones stylisés en une image
polygons_image = styled_polygons.style(**{
    'styleProperty': 'style',
    'neighborhood': 8,
})

# Créer la carte
Map = geemap.Map()
Map.centerObject(roi, 13)

# Ajouter l'image et les polygones à la carte
Map.addLayer(img, {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 3000}, 'Sentinel-2 Image')
Map.addLayer(polygons_image, {}, 'Polygons')

# Créer une carte divisée (splitmap)
left_layer = geemap.ee_tile_layer(img, {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 3000}, 'Sentinel-2 Image')
right_layer = geemap.ee_tile_layer(polygons_image, {}, 'Polygons')
Map.split_map(left_layer, right_layer)

# Afficher la carte
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[60.431876162888365, 17.224244999997214], controls=(ZoomControl(options=['position', 'zoom_in_text'…

# %%
ee.FeatureCollection(m.draw_features).getInfo()

# %% [markdown]
# ## Hand labelling using airplane images

# %%
s2_rgbVis = {'bands' : ['B4','B3','B2'], 'min': 0, 'max': 0.1}
#mask = img.clip(svämängar1).subtract(img.clip(svämängar1).focalMin(20, 'square', 'meters'))
m = geemap.Map()
m.add_basemap('SATELLITE')
m.centerObject(roi,14)
#m.addLayer(img.divide(10000), s2_rgbVis, 'test')
#m.addLayer(mask.selfMask(), {'bands': ['B1'], 'palette' :['yellow']}, 'test1')
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[60.42909015971474, 17.23471649999347], controls=(WidgetControl(options=['position', 'transparent_b…

# %%
svamangar = ee.FeatureCollection(m.draw_features).getInfo()
svamangar
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'type': 'FeatureCollection', 'columns': {}, 'features': []}

# %%
svamangar1 = ee.Geometry.Polygon([[[17.204379, 60.416382],[17.204272, 60.416827],[17.203885, 60.416954],[17.203564, 60.417177],[17.203521, 60.417378],[17.203392, 60.417548],[17.203499, 60.417738],[17.203885, 60.417897],[17.203478, 60.41795],[17.202984, 60.417738],[17.202813, 60.417452],[17.202984, 60.417209],[17.203306, 60.417028],[17.203971, 60.416711],[17.204379, 60.416382]]])
svamangar2 = ee.Geometry.Polygon([[[17.219532, 60.431515],
      [17.22009, 60.431832],
      [17.220819, 60.431684],
      [17.220948, 60.431028],
      [17.220733, 60.430541],
      [17.221205, 60.430138],
      [17.221291, 60.429736],
      [17.220733, 60.429694],
      [17.219918, 60.429672],
      [17.219703, 60.429376],
      [17.219891, 60.42895],
      [17.21987, 60.428701],
      [17.219988, 60.428611],
      [17.220191, 60.428616],
      [17.220288, 60.428722],
      [17.220427, 60.428839],
      [17.222321, 60.419717],
      [17.221591, 60.419124],
      [17.221377, 60.418191],
      [17.22142, 60.417492],
      [17.220132, 60.416687],
      [17.220347, 60.417831],
      [17.220948, 60.41853],
      [17.221377, 60.419865],
      [17.222407, 60.420225]]])
      
svamangar19 =  ee.Geometry.Polygon([[[17.223712, 60.420164],
      [17.222983, 60.419454],
      [17.222618, 60.418914],
      [17.222103, 60.418014],
      [17.221996, 60.417611],
      [17.222446, 60.417399],
      [17.222382, 60.417865],
      [17.222468, 60.418353],
      [17.222811, 60.418607],
      [17.223133, 60.419115],
      [17.223712, 60.420164]]]),

svamangar20 = ee.Geometry.Polygon([[[17.217316, 60.418136],
      [17.217423, 60.418327],
      [17.217681, 60.418385],
      [17.217938, 60.418274],
      [17.218067, 60.418518],
      [17.218013, 60.418719],
      [17.217638, 60.418571],
      [17.217455, 60.418581],
      [17.217477, 60.418735],
      [17.217252, 60.418836],
      [17.216962, 60.418719],
      [17.217144, 60.418428],
      [17.217359, 60.418465],
      [17.217316, 60.418136]]])
      
svamangar21 = ee.Geometry.Polygon([[[17.217981, 60.418158],
      [17.217574, 60.417909],
      [17.217273, 60.417628],
      [17.217692, 60.417395],
      [17.217981, 60.418158]]])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
s1 = svamangar1.union(right=svamangar2, maxError=1)
s4 = s1.union(right=svamangar5, maxError=1)
s5 = s4.union(right=svamangar6, maxError=1)
s6 = s5.union(right=svamangar7, maxError=1)
s7 = s6.union(right=svamangar8, maxError=1)
s8 = s7.union(right=svamangar9, maxError=1)
s9 = s8.union(right=svamangar10, maxError=1)
s10 = s9.union(right=svamangar11, maxError=1)
s11= s10.union(right=svamangar12, maxError=1)
#s12= s11.union(right=svamangar13, maxError=1)
s13= s11.union(right=svamangar14, maxError=1)
s14= s13.union(right=svamangar15, maxError=1)
s15= s14.union(right=svamangar16, maxError=1)
s16= s15.union(right=svamangar17, maxError=1)
s17= s16.union(right=svamangar18, maxError=1)
#s18= s17.union(right=svamangar19, maxError=1)
s19= s17.union(right=svamangar20, maxError=1)
s20 = s19.union(right=svamangar21, maxError=1)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
s2_rgbVis = {'bands' : ['B4','B3','B2'], 'min': 0, 'max': 0.1}
mask = img.clip(bare).subtract(img.clip(bare).focalMin(20, 'square', 'meters'))
m = geemap.Map()
m.add_basemap('SATELLITE')
m.centerObject(roi,14)
#m.addLayer(img.divide(10000), s2_rgbVis, 'test')
m.addLayer(mask.selfMask(), {'bands': ['B1'], 'palette' :['yellow']}, 'test1')
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[60.431876162888365, 17.224244999997214], controls=(WidgetControl(options=['position', 'transparent…

# %%
# Exportez la FeatureCollection vers votre répertoire utilisateur
task = ee.batch.Export.table.toAsset(
    collection=polygons,
    description='Export feature collection',
    assetId='projects/ee-magniermorgane/assets/svamangar_polygons_2023'
)

# Démarrez la tâche d'exportation
task.start()
import time
# Vérifier l'état de la tâche périodiquement
while task.active():
    print(f"Tâche en cours : {task.status()}")
    time.sleep(30)  # Attendre 30 secondes avant de vérifier à nouveau

# Afficher l'état final de la tâche
print(f"Tâche terminée : {task.status()}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Tâche en cours : {'state': 'READY', 'description': 'Export feature collection', 'priority': 100, 'creation_timestamp_ms': 1716798936568, 'update_timestamp_ms': 1716798936568, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'TE7HI36MKYJ2I6GVHQFVYWTT', 'name': 'projects/earthengine-legacy/operations/TE7HI36MKYJ2I6GVHQFVYWTT'}
# Tâche en cours : {'state': 'RUNNING', 'description': 'Export feature collection', 'priority': 100, 'creation_timestamp_ms': 1716798936568, 'update_timestamp_ms': 1716798944813, 'start_timestamp_ms': 1716798944733, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'TE7HI36MKYJ2I6GVHQFVYWTT', 'name': 'projects/earthengine-legacy/operations/TE7HI36MKYJ2I6GVHQFVYWTT'}
# Tâche terminée : {'state': 'COMPLETED', 'description': 'Export feature collection', 'priority': 100, 'creation_timestamp_ms': 1716798936568, 'update_timestamp_ms': 1716798983865, 'start_timestamp_ms': 1716798944733, 'task_type': 'EXPORT_FEATURES', 'destination_uris': ['https://code.earthengine.google.com/?asset=projects/ee-magniermorgane/assets/svamangar_polygons_2023'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.07461412250995636, 'id': 'TE7HI36MKYJ2I6GVHQFVYWTT', 'name': 'projects/earthengine-legacy/operations/TE7HI36MKYJ2I6GVHQFVYWTT'}

# %%
polygons = ee.FeatureCollection('projects/ee-magniermorgane/assets/svamangar_polygons_2023')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
display(polygons)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div><style>:root {
#   --font-color-primary: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --font-color-secondary: var(--jp-content-font-color2, rgba(0, 0, 0, 0.6));
#   --font-color-accent: rgba(123, 31, 162, 1);
#   --border-color: var(--jp-border-color2, #e0e0e0);
#   --background-color: var(--jp-layout-color0, white);
#   --background-color-row-even: var(--jp-layout-color1, white);
#   --background-color-row-odd: var(--jp-layout-color2, #eeeeee);
# }
#
# html[theme="dark"],
# body[data-theme="dark"],
# body.vscode-dark {
#   --font-color-primary: rgba(255, 255, 255, 1);
#   --font-color-secondary: rgba(255, 255, 255, 0.6);
#   --font-color-accent: rgb(173, 132, 190);
#   --border-color: #2e2e2e;
#   --background-color: #111111;
#   --background-color-row-even: #111111;
#   --background-color-row-odd: #313131;
# }
#
# .ee {
#   padding: 1em;
#   line-height: 1.5em;
#   min-width: 300px;
#   max-width: 1200px;
#   overflow-y: scroll;
#   max-height: 600px;
#   border: 1px solid var(--border-color);
#   font-family: monospace;
# }
#
# .ee li {
#   list-style-type: none;
# }
#
# .ee ul {
#   padding-left: 1.5em !important;
#   margin: 0;
# }
#
# .ee > ul {
#   padding-left: 0 !important;
# }
#
# .ee-open,
# .ee-shut {
#   color: var(--font-color-secondary);
#   cursor: pointer;
#   margin: 0;
# }
#
# .ee-open:hover,
# .ee-shut:hover {
#   color: var(--font-color-primary);
# }
#
# .ee-k {
#   color: var(--font-color-accent);
#   margin-right: 6px;
# }
#
# .ee-v {
#   color: var(--font-color-primary);
# }
#
# .ee-toggle {
#   display: none;
# }
#
# .ee-shut + ul {
#   display: none;
# }
#
# .ee-open + ul {
#   display: block;
# }
#
# .ee-shut::before {
#   display: inline-block;
#   content: "▼";
#   margin-right: 6px;
#   transform: rotate(-90deg);
#   transition: transform 0.2s;
# }
#
# .ee-open::before {
#   transform: rotate(0deg);
#   display: inline-block;
#   content: "▼";
#   margin-right: 6px;
#   transition: transform 0.2s;
# }
# </style><div class='ee'><ul><li><label class='ee-shut'>FeatureCollection projects/ee-magniermorgane/assets/svamangar_polygons_2023  (5 elements, 2 columns)<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>type:</span><span class='ee-v'>FeatureCollection</span></li><li><span class='ee-k'>id:</span><span class='ee-v'>projects/ee-magniermorgane/assets/svamangar_polygons_2023</span></li><li><span class='ee-k'>version:</span><span class='ee-v'>1716727992241081</span></li><li><label class='ee-shut'>columns: Object (2 properties)<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>class:</span><span class='ee-v'>Integer</span></li><li><span class='ee-k'>system:index:</span><span class='ee-v'>String</span></li></ul></li><li><label class='ee-shut'>properties: Object (1 property)<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>system:asset_size:</span><span class='ee-v'>14431</span></li></ul></li><li><label class='ee-shut'>features: List (5 elements)<input type='checkbox' class='ee-toggle'></label><ul><li><label class='ee-shut'>0: Feature (MultiPolygon, 1 property)<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>type:</span><span class='ee-v'>Feature</span></li><li><span class='ee-k'>id:</span><span class='ee-v'>00000000000000000000</span></li><li><label class='ee-shut'>geometry: MultiPolygon (4 vertices)<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>type:</span><span class='ee-v'>MultiPolygon</span></li><li><label class='ee-shut'>coordinates: List (19 elements)<input type='checkbox' class='ee-toggle'></label><ul><li><label class='ee-shut'>0: List (1 element)<input type='checkbox' class='ee-toggle'></label><ul><li><label class='ee-shut'>0: List (4 elements)<input type='checkbox' class='ee-toggle'></label><ul><li><label class='ee-shut'>0: [17.228037221587954, 60.42756217136897]<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>0:</span><span class='ee-v'>17.228037221587954</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>60.42756217136897</span></li></ul></li><li><label class='ee-shut'>1: [17.228055995113536, 60.42757300367754]<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>0:</span><span class='ee-v'>17.228055995113536</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>60.42757300367754</span></li></ul></li><li><label class='ee-shut'>2: [17.22804625217278, 60.42757868328257]<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>0:</span><span class='ee-v'>17.22804625217278</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>60.42757868328257</span></li></ul></li><li><label class='ee-shut'>3: [17.228037221587954, 60.42756217136897]<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>0:</span><span class='ee-v'>17.228037221587954</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>60.42756217136897</span></li></ul></li></ul></li></ul></li><li><label class='ee-shut'>1: List (1 element)<input type='checkbox' class='ee-toggle'></label><ul><li><label class='ee-shut'>0: List (5 elements)<input type='checkbox' class='ee-toggle'></label><ul><li><label class='ee-shut'>0: [17.24079617288346, 60.44671507760903]<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>0:</span><span class='ee-v'>17.24079617288346</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>60.44671507760903</span></li></ul></li><li><label class='ee-shut'>1: [17.24078190576237, 60.446650126942316]<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>0:</span><span class='ee-v'>17.24078190576237</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>60.446650126942316</span></li></ul></li><li><label class='ee-shut'>2: [17.241514373912693, 60.4463254681685]<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>0:</span><span class='e ...
